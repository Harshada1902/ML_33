# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
>>> import pandas as pd
>>> import numpy as np

# %%
df=pd.read_csv("C:\\Users\\HP\\Downloads\\amazon_best_sellers_gaming_merchandise_2024.csv")

# %%
df.head(5)
# Out:
#                                                title             brand  \
# 0  Do Not Disturb I'm Gaming Socks,Valentines Day...            Kelool
# 1  Razer Tartarus V2 Gaming Keypad: Mecha-Membran...             Razer
# 2  Neon Gaming Decor for Boys Room Wooden, Neon G...        Simimi art
# 3  I Paused My Game to Be Here Video Gamer Mens R...  Feelin Good Tees
# 4  Neon Sign King Boo The Ghost Face LED Neon Lig...           JOSEBRU
#
#                                          description  stars  reviewsCount  \
# 0                                                NaN    4.7         926.0
# 1  The Razer Tartarus V2 provides endless command...    4.4       15386.0
# 2                                                NaN    4.4          25.0
# 3  The best part is when you pull this shirt over...    4.7       18918.0
# 4                                                NaN    4.7         536.0
#
#   price/currency  price/value  \
# 0            NaN          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           259 non-null    object
#  1   brand           256 non-null    object
#  2   description     138 non-null    object
#  3   stars           227 non-null    float64
#  4   reviewsCount    227 non-null    float64
#  5   price/currency  190 non-null    object
#  6   price/value     190 non-null    float64
#  7   breadCrumbs     239 non-null    object
#  8   asin            259 non-null    object
#  9   url             259 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 20.4+ KB

# %%
to_drop=['asin']
df.drop(to_drop, inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           259 non-null    object
#  1   brand           256 non-null    object
#  2   description     138 non-null    object
#  3   stars           227 non-null    float64
#  4   reviewsCount    227 non-null    float64
#  5   price/currency  190 non-null    object
#  6   price/value     190 non-null    float64
#  7   breadCrumbs     239 non-null    object
#  8   url             259 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 18.3+ KB

# %%
df.head(20)
# Out:
#                                                 title  \
# 0   Do Not Disturb I'm Gaming Socks,Valentines Day...
# 1   Razer Tartarus V2 Gaming Keypad: Mecha-Membran...
# 2   Neon Gaming Decor for Boys Room Wooden, Neon G...
# 3   I Paused My Game to Be Here Video Gamer Mens R...
# 4   Neon Sign King Boo The Ghost Face LED Neon Lig...
# 5   Paladone Xbox Light Up Headphone Stand, Gamer ...
# 6   Paladone Yoshi Egg Light 8 in x 7 in | Super M...
# 7   Super Mario Warp Pipe Travel Mug - 15oz Stainl...
# 8   Gamer Gifts, Gifts For Gamers, Gifts For Gamer...
# 9   JENVIO Gamer Gifts for Men - Gamer Mode ON - S...
# 10  I Paused My Game to Be Here | Funny Video Game...
# 11  Sure, Right After This Raid Funny Gift For Gam...
# 12  Paladone Super Mario Bros Mushroom Light with ...
# 13  Exquisite Gaming: Fallout 76: Variant Vault Bo...
# 14  Gaming Apparel - Gamer Gifts for Teen Boys & M...
# 15  Paladone Playstation Controller Digital Alarm ...
# ...

# %%
df.loc[100]
# Out:
# title             PlayStation Launch Collection "Crossbody" Shou...
# brand                                               Controller Gear
# description       This PlayStation launch collection “crossbody”...
# stars                                                           3.4
# reviewsCount                                                   16.0
# price/currency                                                    $
# price/value                                                   24.99
# breadCrumbs                                                     NaN
# url                            https://www.amazon.com/dp/B08MB63BDZ
# Name: 100, dtype: object

# %%
df.tail()
# Out:
#                                                  title     brand  \
# 254  Gamer Gifts for Teenage Boy, Gamer Room Decor ...  Slothoem
# 255  Gamer Tumbler Gifts,Gamer Gifts For Men Teen B...   YOPIGOT
# 256  Divoom Pixoo-64 - WiFi Pixel Cloud Digital Fra...    Divoom
# 257  Custom Game Blanket for Boys and Girls, Miner ...   PLOMCAC
# 258  Gaming Blanket Game Flannel Throw Blanket 60"x...    Seimip
#
#                                            description  stars  reviewsCount  \
# 254                                                NaN    4.6         276.0
# 255                                                NaN    4.5          27.0
# 256                                                NaN    4.0         909.0
# 257  Custom Game Blanket for Boys and Girls, Miner ...    NaN           NaN
# 258                                                NaN    4.3          18.0
#
#     price/currency  price/value  \
# 254              $        19.75
# 255              $        23.99
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 254    False
# 255    False
# 256    False
# 257    False
# 258    False
# Length: 259, dtype: bool

# %%
df.isnull()
# Out:
#      title  brand  description  stars  reviewsCount  price/currency  \
# 0    False  False         True  False         False            True
# 1    False  False        False  False         False           False
# 2    False  False         True  False         False           False
# 3    False  False        False  False         False            True
# 4    False  False         True  False         False           False
# ..     ...    ...          ...    ...           ...             ...
# 254  False  False         True  False         False           False
# 255  False  False         True  False         False           False
# 256  False  False         True  False         False           False
# 257  False  False        False   True          True           False
# 258  False  False         True  False         False           False
#
#      price/value  breadCrumbs    url
# 0           True        False  False
# 1          False        False  False
# ...

# %%
df.loc[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [title, brand, description, stars, reviewsCount, price/currency, price/value, breadCrumbs, url]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           259 non-null    object
#  1   brand           256 non-null    object
#  2   description     138 non-null    object
#  3   stars           227 non-null    float64
#  4   reviewsCount    227 non-null    float64
#  5   price/currency  190 non-null    object
#  6   price/value     190 non-null    float64
#  7   breadCrumbs     239 non-null    object
#  8   url             259 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 18.3+ KB
